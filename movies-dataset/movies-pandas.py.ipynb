# %%
import pandas as pd

# %%
movie_data=pd.read_csv(r"C:\Users\rafal\Videos\python-training-with-kumar-lecturs\practice and notes\practice-pandas-on-anaconda\data-sets\TMDB 10000 Movies Dataset.csv")

# %%
movie_data
# Out:
#           id original_language             original_title  \
# 0     851644                ko                    20세기 소녀
# 1        238                en              The Godfather
# 2        278                en   The Shawshank Redemption
# 3        240                en      The Godfather Part II
# 4     667257                es           Cosas imposibles
# ...      ...               ...                        ...
# 9995   11375                en         Hollywood Homicide
# 9996  298614                fr  Une heure de tranquillité
# 9997   50357                en                  Apollo 18
# 9998   97795                en                     Emergo
# 9999   11822                de                Nekromantik
#
#                                                overview  popularity  \
# 0     Yeon-du asks her best friend Bora to collect a...     170.540
# 1     Spanning the years 1945 to 1955, a chronicle o...      86.518
# ...

# %%
head_data=movie_data.head()
df = pd.DataFrame(head_data)










# print(movie_data.describe())

# %%
df
# Out:
#        id original_language            original_title  \
# 0  851644                ko                   20세기 소녀
# 1     238                en             The Godfather
# 2     278                en  The Shawshank Redemption
# 3     240                en     The Godfather Part II
# 4  667257                es          Cosas imposibles
#
#                                             overview  popularity release_date  \
# 0  Yeon-du asks her best friend Bora to collect a...     170.540   2022-10-06
# 1  Spanning the years 1945 to 1955, a chronicle o...      86.518   1972-03-14
# 2  Framed in the 1940s for the double murder of h...      84.681   1994-09-23
# 3  In the continuing saga of the Corleone crime f...      44.957   1974-12-20
# 4  Matilde is a woman who, after the death of her...      32.859   2021-06-17
#
#                       title  vote_average  vote_count
# 0         20th Century Girl           8.7         290
# 1             The Godfather           8.7       16988
# ...

# %%
pd.DataFrame(head_data)
df=pd.DataFrame(movie_data.head(10))

# %%
df
# Out:
#        id original_language                original_title  \
# 0  851644                ko                       20세기 소녀
# 1     238                en                 The Godfather
# 2     278                en      The Shawshank Redemption
# 3     240                en         The Godfather Part II
# 4  667257                es              Cosas imposibles
# 5   19404                hi  दिलवाले दुल्हनिया ले जायेंगे
# 6     424                en              Schindler's List
# 7  620249                zh                         罗小黑战记
# 8  372754                ja                           同級生
# 9     129                ja                      千と千尋の神隠し
#
#                                             overview  popularity release_date  \
# 0  Yeon-du asks her best friend Bora to collect a...     170.540   2022-10-06
# 1  Spanning the years 1945 to 1955, a chronicle o...      86.518   1972-03-14
# 2  Framed in the 1940s for the double murder of h...      84.681   1994-09-23
# ...

# %%
df=pd.DataFrame(movie_data.tail(10))

# %%
df
# Out:
#           id original_language             original_title  \
# 9990  611468                de          Kidnapping Stella
# 9991   71254                en                      Arena
# 9992  553141                en            The Head Hunter
# 9993  154512                it           Colpi di fulmine
# 9994  505177                en                    10 x 10
# 9995   11375                en         Hollywood Homicide
# 9996  298614                fr  Une heure de tranquillité
# 9997   50357                en                  Apollo 18
# 9998   97795                en                     Emergo
# 9999   11822                de                Nekromantik
#
#                                                overview  popularity  \
# 9990  Snatched off the street and held for ransom, a...      10.932
# 9991  David Lord finds himself forced into the savag...      12.101
# 9992  On the outskirts of a kingdom, a quiet but fie...      11.145
# ...

# %%
df=pd.DataFrame(movie_data.columns)

# %%
df
# Out:
#                    0
# 0                 id
# 1  original_language
# 2     original_title
# 3           overview
# 4         popularity
# 5       release_date
# 6              title
# 7       vote_average
# 8         vote_count

# %%
df=pd.DataFrame(movie_data.index)

# %%
df
# Out:
#          0
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
# ...    ...
# 9995  9995
# 9996  9996
# 9997  9997
# 9998  9998
# 9999  9999
#
# [10000 rows x 1 columns]

# %%
df=pd.DataFrame(movie_data['title'][1:20:1])

# %%
df
# Out:
#                              title
# 1                    The Godfather
# 2         The Shawshank Redemption
# 3            The Godfather Part II
# 4                Impossible Things
# 5      Dilwale Dulhania Le Jayenge
# 6                 Schindler's List
# 7                The Legend of Hei
# 8         Dou kyu sei – Classmates
# 9                    Spirited Away
# 10                    12 Angry Men
# 11                      Your Name.
# 12                        Parasite
# 13                  The Green Mile
# 14                 The Dark Knight
# 15      Gabriel's Inferno: Part II
# 16               Gabriel's Inferno
# 17                    Pulp Fiction
# 18  The Good, the Bad and the Ugly
# 19       Burn the Stage: The Movie

# %%
film_title=movie_data['title'][10]
# dt=pd.DataFrame(film_title)

# %%
film_title
# Out:
# '12 Angry Men'
